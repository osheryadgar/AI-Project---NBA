# %%
import pandas as pd
from nba_api.stats.static import players, teams
from nba_api.stats.endpoints import playergamelog, playbyplay, playbyplayv2, alltimeleadersgrids
from nba_api.stats.endpoints import FranchiseLeaders, CommonPlayerInfo

# %%
# Define the player ID
deni = players.get_players()
All_Players = pd.DataFrame(deni)
All_Players
# Out:
#            id            full_name first_name     last_name  is_active
# 0       76001       Alaa Abdelnaby       Alaa     Abdelnaby      False
# 1       76002      Zaid Abdul-Aziz       Zaid    Abdul-Aziz      False
# 2       76003  Kareem Abdul-Jabbar     Kareem  Abdul-Jabbar      False
# 3          51   Mahmoud Abdul-Rauf    Mahmoud    Abdul-Rauf      False
# 4        1505    Tariq Abdul-Wahad      Tariq   Abdul-Wahad      False
# ...       ...                  ...        ...           ...        ...
# 4826  1627790           Ante Zizic       Ante         Zizic      False
# 4827    78647             Jim Zoet        Jim          Zoet      False
# 4828    78648            Bill Zopf       Bill          Zopf      False
# 4829  1627826          Ivica Zubac      Ivica         Zubac       True
# 4830    78650           Matt Zunic       Matt         Zunic      False
#
# [4831 rows x 5 columns]

# %%
# Search for players that match the name "Deni Avdija" and Get the first player in the search results
deni = players.find_players_by_full_name("leBron james")[0]
deni
# Out:
# {'id': 2544,
#  'full_name': 'LeBron James',
#  'first_name': 'LeBron',
#  'last_name': 'James',
#  'is_active': True}

# %%
# Extract the player's ID
deni_id = deni["id"]

# Get the player's game log
gamelog = playergamelog.PlayerGameLog(player_id=deni_id)

# Create a DataFrame from the player's game log
df_deni_games = gamelog.get_data_frames()[0]

pd.set_option('display.max_columns', None)
df_deni_games
# Out:
#    SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0      22022       2544  0022200821  FEB 07, 2023  LAL vs. OKC  L   34   13
# 1      22022       2544  0022200798  FEB 04, 2023    LAL @ NOP  L   40   10
# 2      22022       2544  0022200778  FEB 02, 2023    LAL @ IND  W   33   11
# 3      22022       2544  0022200765  JAN 31, 2023    LAL @ NYK  W   43   11
# 4      22022       2544  0022200749  JAN 28, 2023    LAL @ BOS  L   44   15
# 5      22022       2544  0022200729  JAN 25, 2023  LAL vs. SAS  W   35    8
# 6      22022       2544  0022200719  JAN 24, 2023  LAL vs. LAC  L   33   16
# 7      22022       2544  0022200705  JAN 22, 2023    LAL @ POR  W   36   14
# 8      22022       2544  0022200690  JAN 20, 2023  LAL vs. MEM  W   37    8
# 9      22022       2544  0022200677  JAN 18, 2023  LAL vs. SAC  L   37   11
# 10     22022       2544  0022200664  JAN 16, 2023  LAL vs. HOU  W   36   16
# ...

# %%
pbp2_deni = playbyplayv2.PlayByPlayV2(game_id='0022200787')
df_pbp2_deni = pbp2_deni.get_data_frames()[0]
df_pbp2_deni.head(20)
# Out:
#        GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 0   0022200787         2            12                   0       1
# 1   0022200787         4            10                   0       1
# 2   0022200787         7             2                  78       1
# 3   0022200787         8             4                   0       1
# 4   0022200787         9             1                  97       1
# 5   0022200787        10             2                  83       1
# 6   0022200787        11             4                   0       1
# 7   0022200787        12             6                   2       1
# 8   0022200787        14             3                  11       1
# 9   0022200787        15             3                  12       1
# 10  0022200787        16             2                  63       1
# 11  0022200787        17             4                   0       1
# 12  0022200787        18             1                 108       1
# ...

# %%
WSH = teams.get_teams()
WSH
# Out:
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Atlanta',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970},
#  {'id': 1610612740,
#   'full_name': 'New Orleans Pelicans',
#   'abbreviation': 'NOP',
#   'nickname': 'Pelicans',
#   'city': 'New Orleans',
#   'state': 'Louisiana',
#   'year_founded': 2002},
#  {'id': 1610612741,
#   'full_name': 'Chicago Bulls',
#   'abbreviation': 'CHI',
#   'nickname': 'Bulls',
#   'city': 'Chicago',
#   'state': 'Illinois',
#   'year_founded': 1966},
#  {'id': 1610612742,
# ...

# %%
FranchiseLeaders(team_id=1610612747).get_data_frames()[0]
# Out:
#       TEAM_ID    PTS  PTS_PERSON_ID   PTS_PLAYER    AST  AST_PERSON_ID  \
# 0  1610612747  33643            977  Kobe Bryant  10141          77142
#
#       AST_PLAYER    REB  REB_PERSON_ID    REB_PLAYER   BLK  BLK_PERSON_ID  \
# 0  Magic Johnson  11463          76127  Elgin Baylor  2694          76003
#
#             BLK_PLAYER   STL  STL_PERSON_ID   STL_PLAYER
# 0  Kareem Abdul-Jabbar  1944            977  Kobe Bryant

# %%
CommonPlayerInfo(player_id=deni_id).get_data_frames()[0]
# Out:
#    PERSON_ID FIRST_NAME LAST_NAME DISPLAY_FIRST_LAST DISPLAY_LAST_COMMA_FIRST  \
# 0       2544     LeBron     James       LeBron James            James, LeBron
#
#   DISPLAY_FI_LAST   PLAYER_SLUG            BIRTHDATE  \
# 0        L. James  lebron-james  1984-12-30T00:00:00
#
#                          SCHOOL COUNTRY                  LAST_AFFILIATION  \
# 0  St. Vincent-St. Mary HS (OH)     USA  St. Vincent-St. Mary HS (OH)/USA
#
#   HEIGHT WEIGHT  SEASON_EXP JERSEY POSITION ROSTERSTATUS  \
# 0    6-9    250          19      6  Forward       Active
#
#   GAMES_PLAYED_CURRENT_SEASON_FLAG     TEAM_ID TEAM_NAME TEAM_ABBREVIATION  \
# 0                                Y  1610612747    Lakers               LAL
#
#   TEAM_CODE    TEAM_CITY    PLAYERCODE  FROM_YEAR  TO_YEAR DLEAGUE_FLAG  \
# 0    lakers  Los Angeles  lebron_james       2003     2022            N
#
#   NBA_FLAG GAMES_PLAYED_FLAG DRAFT_YEAR DRAFT_ROUND DRAFT_NUMBER  \
# ...

# %%
alltimeleadersgrids.AllTimeLeadersGrids().get_data_frames()[0]
# Out:
#    PLAYER_ID          PLAYER_NAME    GP  GP_RANK IS_ACTIVE_FLAG
# 0        305        Robert Parish  1611        1              N
# 1      76003  Kareem Abdul-Jabbar  1560        2              N
# 2       1713         Vince Carter  1541        3              N
# 3       1717        Dirk Nowitzki  1522        4              N
# 4        304        John Stockton  1504        5              N
# 5        252          Karl Malone  1476        6              N
# 6        708        Kevin Garnett  1462        7              N
# 7        788         Kevin Willis  1424        8              N
# 8       1891          Jason Terry  1410        9              N
# 9       2544         LeBron James  1410        9              Y

# %%
from nba_api.live.nba.endpoints import scoreboard 

# Today's Score Board
Today_score = scoreboard.ScoreBoard().games.get_dict()
Today_score_df = pd.DataFrame(Today_score)
Today_score_df["homeTeam"][0]
# Out:
# {'teamId': 1610612739,
#  'teamName': 'Cavaliers',
#  'teamCity': 'Cleveland',
#  'teamTricode': 'CLE',
#  'wins': 35,
#  'losses': 22,
#  'score': 113,
#  'seed': None,
#  'inBonus': None,
#  'timeoutsRemaining': 1,
#  'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 32},
#   {'period': 2, 'periodType': 'REGULAR', 'score': 19},
#   {'period': 3, 'periodType': 'REGULAR', 'score': 25},
#   {'period': 4, 'periodType': 'REGULAR', 'score': 37}]}

# %%
from nba_api.stats.endpoints import playerawards
playerawards.PlayerAwards(player_id=2544).get_data_frames()[0]
# Out:
#      PERSON_ID FIRST_NAME LAST_NAME                 TEAM  \
# 0         2544     LeBron     James  Cleveland Cavaliers
# 1         2544     LeBron     James  Cleveland Cavaliers
# 2         2544     LeBron     James           Miami Heat
# 3         2544     LeBron     James           Miami Heat
# 4         2544     LeBron     James           Miami Heat
# ..         ...        ...       ...                  ...
# 146       2544     LeBron     James                  USA
# 147       2544     LeBron     James                  USA
# 148       2544     LeBron     James                  USA
# 149       2544     LeBron     James   Los Angeles Lakers
# 150       2544     LeBron     James   Los Angeles Lakers
#
#                 DESCRIPTION ALL_NBA_TEAM_NUMBER   SEASON MONTH  \
# 0        All-Defensive Team                   1  2008-09  None
# 1        All-Defensive Team                   1  2009-10  None
# 2        All-Defensive Team                   1  2010-11  None
# ...

# %%
games = scoreboard.ScoreBoard()

# json
games.get_json()
# Out:
# '{"meta": {"version": 1, "request": "https://nba-prod-us-east-1-mediaops-stats.s3.amazonaws.com/NBA/liveData/scoreboard/todaysScoreboard_00.json", "time": "2023-02-09 10:57:27.5727", "code": 200}, "scoreboard": {"gameDate": "2023-02-08", "leagueId": "00", "leagueName": "National Basketball Association", "games": [{"gameId": "0022200822", "gameCode": "20230208/DETCLE", "gameStatus": 3, "gameStatusText": "Final", "period": 4, "gameClock": "", "gameTimeUTC": "2023-02-09T00:00:00Z", "gameEt": "2023-02-08T19:00:00Z", "regulationPeriods": 4, "ifNecessary": false, "seriesGameNumber": "", "seriesText": "", "homeTeam": {"teamId": 1610612739, "teamName": "Cavaliers", "teamCity": "Cleveland", "teamTricode": "CLE", "wins": 35, "losses": 22, "score": 113, "seed": null, "inBonus": null, "timeoutsRemaining": 1, "periods": [{"period": 1, "periodType": "REGULAR", "score": 32}, {"period": 2, "periodType": "REGULAR", "score": 19}, {"period": 3, "periodType": "REGULAR", "score": 25}, {"period": 4, "peri
# ...

# %%
from nba_api.stats.endpoints import BoxScoreAdvancedV2, BoxScorePlayerTrackV2, CumeStatsPlayer

# %%
box1 = BoxScoreAdvancedV2(game_id='0022101217').get_data_frames()[0]
box1.head()
# Out:
#       GAME_ID     TEAM_ID TEAM_ABBREVIATION   TEAM_CITY  PLAYER_ID  \
# 0  0022101217  1610612764               WAS  Washington    1630166
# 1  0022101217  1610612764               WAS  Washington    1629060
# 2  0022101217  1610612764               WAS  Washington    1629655
# 3  0022101217  1610612764               WAS  Washington    1630557
# 4  0022101217  1610612764               WAS  Washington     203107
#
#         PLAYER_NAME NICKNAME START_POSITION COMMENT    MIN  E_OFF_RATING  \
# 0       Deni Avdija     Deni              F          31:08         110.8
# 1     Rui Hachimura      Rui              F          32:20         113.2
# 2    Daniel Gafford   Daniel              C          27:58         122.6
# 3     Corey Kispert    Corey              G          25:37         123.9
# 4  Tomas Satoransky    Tomas              G          20:16         121.9
#
#    OFF_RATING  E_DEF_RATING  DEF_RATING  E_NET_RATING  NET_RATING  AST_PCT  \
# ...

# %%
box2 = BoxScorePlayerTrackV2(game_id='0022101217')
box2
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1346             try:
# ...

# %%
box3 = CumeStatsPlayer(player_id='1630166', game_ids='0022101217').get_data_frames()[0]
for i in box3.columns:
    for j in
# Out:
# Index(['DATE_EST', 'VISITOR_TEAM', 'HOME_TEAM', 'GP', 'GS', 'ACTUAL_MINUTES',
#        'ACTUAL_SECONDS', 'FG', 'FGA', 'FG_PCT', 'FG3', 'FG3A', 'FG3_PCT', 'FT',
#        'FTA', 'FT_PCT', 'OFF_REB', 'DEF_REB', 'TOT_REB', 'AVG_TOT_REB', 'AST',
#        'PF', 'DQ', 'STL', 'TURNOVERS', 'BLK', 'PTS', 'AVG_PTS'],
#       dtype='object')

# %%
df_league_standings = LeagueStandingsV3(season_type='Regular Season').get_data_frames()[0]
df_league_standings.head()

check_data_quality(df_league_standings) 

df_league_standings = df_league_standings.dropna(axis='columns')
df_league_standings.columns

df_stats_all_year_preprocess.columns

df_league_standings = df_league_standings.rename(columns=lambda x: x + '_team')
merged_df = df_stats_all_year_preprocess.merge(df_league_standings, left_on='TEAM_ID', right_on='TeamID_team')
merged_df
